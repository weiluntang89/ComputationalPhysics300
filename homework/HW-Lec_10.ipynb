# %% [markdown]
# # Introduction

# %% [markdown]
# Weilun Tang

# %% [markdown]
# Written by 09/26/2021

# %% [markdown]
# This program is to demonstrate the application of Fourier transformation. The application in this program is Fourier-transform ion cyclontron resonance mass spectrometry. The ions are trapped and rotated at certain frequency. First, record the raw data. Then, use Fourier transformation and plot data in the frequency domain. Finally, one can change the frequency domain data to mass-to-charge ratio domain.

# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Main Loop

# %%
arr = np.loadtxt("fennelraw.txt") 
plt.plot(x,arr)
plt.xlabel('Time(s)')
plt.ylabel('Amplitude')
plt.title('Amplitude vs Time')
plt.show()

fft = np.fft.fft(arr)
plt.plot(x,abs(fft))
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.title('Amplitude vs Frequency')
plt.show()

# %% [markdown]
# The first figure is the data in time domain, and the second figure is the data in frequency domain. The data in time domain contains noises and it is difficult to analyze. After use FFT, the data in frequency domain shows the dominant frequency. Finally, one can convert frequency domain to mass-to-charge ratio domain in order to find the abundance of the ions.
